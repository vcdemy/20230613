# %% [markdown]
# <a href="https://colab.research.google.com/github/vcdemy/20230613/blob/main/20230725%E7%AD%86%E8%A8%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 20230725 筆記

# %% [markdown]
# # Pandas簡介

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 產生練習用資料集

# %%
np.random.randint(20, 101, 10)
# Out:
# array([ 71,  26,  94,  41,  83,  50, 100,  76,  82,  41])

# %%
np.random.randint(20, 101, (10, 4))
# Out:
# array([[58, 81, 61, 81],
#        [92, 25, 86, 43],
#        [23, 38, 40, 61],
#        [51, 80, 94, 44],
#        [36, 91, 97, 77],
#        [61, 63, 92, 63],
#        [64, 26, 34, 40],
#        [82, 98, 60, 89],
#        [87, 99, 93, 21],
#        [78, 97, 63, 65]])

# %%
data = np.random.randint(20, 101, (10, 4))

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     0    1   2   3
# 0  92   20  65  28
# 1  97   75  32  63
# 2  22   20  46  37
# 3  32   20  70  80
# 4  53   37  62  69
# 5  41   31  78  81
# 6  54   66  97  43
# 7  36   68  66  84
# 8  49   82  86  37
# 9  26  100  44  79

# %%
df.columns = ['國文','英文','數學','理化']

# %%
df
# Out:
#    國文   英文  數學  理化
# 0  92   20  65  28
# 1  97   75  32  63
# 2  22   20  46  37
# 3  32   20  70  80
# 4  53   37  62  69
# 5  41   31  78  81
# 6  54   66  97  43
# 7  36   68  66  84
# 8  49   82  86  37
# 9  26  100  44  79

# %%
df.index = ['蕭念宜','林慧萍','周哲維','張雅君','吳于庭',
            '關詩婷','黃韻宇','張侑花','李志文','陳如君']

# %%
df
# Out:
#      國文   英文  數學  理化
# 蕭念宜  92   20  65  28
# 林慧萍  97   75  32  63
# 周哲維  22   20  46  37
# 張雅君  32   20  70  80
# 吳于庭  53   37  62  69
# 關詩婷  41   31  78  81
# 黃韻宇  54   66  97  43
# 張侑花  36   68  66  84
# 李志文  49   82  86  37
# 陳如君  26  100  44  79

# %% [markdown]
# ## 檢視DataFrame的屬性

# %%
df
# Out:
#      國文   英文  數學  理化
# 蕭念宜  92   20  65  28
# 林慧萍  97   75  32  63
# 周哲維  22   20  46  37
# 張雅君  32   20  70  80
# 吳于庭  53   37  62  69
# 關詩婷  41   31  78  81
# 黃韻宇  54   66  97  43
# 張侑花  36   68  66  84
# 李志文  49   82  86  37
# 陳如君  26  100  44  79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 蕭念宜 to 陳如君
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   國文      10 non-null     int64
#  1   英文      10 non-null     int64
#  2   數學      10 non-null     int64
#  3   理化      10 non-null     int64
# dtypes: int64(4)
# memory usage: 700.0+ bytes

# %%
df.head()
# Out:
#      國文  英文  數學  理化
# 蕭念宜  92  20  65  28
# 林慧萍  97  75  32  63
# 周哲維  22  20  46  37
# 張雅君  32  20  70  80
# 吳于庭  53  37  62  69

# %%
df.tail()
# Out:
#      國文   英文  數學  理化
# 關詩婷  41   31  78  81
# 黃韻宇  54   66  97  43
# 張侑花  36   68  66  84
# 李志文  49   82  86  37
# 陳如君  26  100  44  79

# %% [markdown]
# ## 讀取特定欄(Column)

# %% [markdown]
# ### 讀取所有人的數學成績

# %%
df['數學']
# Out:
# 蕭念宜    65
# 林慧萍    32
# 周哲維    46
# 張雅君    70
# 吳于庭    62
# 關詩婷    78
# 黃韻宇    97
# 張侑花    66
# 李志文    86
# 陳如君    44
# Name: 數學, dtype: int64

# %%
type(df['數學'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### 同時讀取兩個欄位

# %%
df[['數學','理化']]
# Out:
#      數學  理化
# 蕭念宜  65  28
# 林慧萍  32  63
# 周哲維  46  37
# 張雅君  70  80
# 吳于庭  62  69
# 關詩婷  78  81
# 黃韻宇  97  43
# 張侑花  66  84
# 李志文  86  37
# 陳如君  44  79

# %%
type(df[['數學','理化']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['數學']]
# Out:
#      數學
# 蕭念宜  65
# 林慧萍  32
# 周哲維  46
# 張雅君  70
# 吳于庭  62
# 關詩婷  78
# 黃韻宇  97
# 張侑花  66
# 李志文  86
# 陳如君  44

# %%
type(df[['數學']])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      國文   英文  數學  理化
# 蕭念宜  92   20  65  28
# 林慧萍  97   75  32  63
# 周哲維  22   20  46  37
# 張雅君  32   20  70  80
# 吳于庭  53   37  62  69
# 關詩婷  41   31  78  81
# 黃韻宇  54   66  97  43
# 張侑花  36   68  66  84
# 李志文  49   82  86  37
# 陳如君  26  100  44  79

# %%
df[['數學','理化','國文','英文']]
# Out:
#      數學  理化  國文   英文
# 蕭念宜  65  28  92   20
# 林慧萍  32  63  97   75
# 周哲維  46  37  22   20
# 張雅君  70  80  32   20
# 吳于庭  62  69  53   37
# 關詩婷  78  81  41   31
# 黃韻宇  97  43  54   66
# 張侑花  66  84  36   68
# 李志文  86  37  49   82
# 陳如君  44  79  26  100

# %% [markdown]
# ## 讀取特定的列(Row) - 使用 .loc 及 .iloc

# %%
df
# Out:
#      國文   英文  數學  理化
# 蕭念宜  92   20  65  28
# 林慧萍  97   75  32  63
# 周哲維  22   20  46  37
# 張雅君  32   20  70  80
# 吳于庭  53   37  62  69
# 關詩婷  41   31  78  81
# 黃韻宇  54   66  97  43
# 張侑花  36   68  66  84
# 李志文  49   82  86  37
# 陳如君  26  100  44  79

# %%
df.loc['周哲維']
# Out:
# 國文    22
# 英文    20
# 數學    46
# 理化    37
# Name: 周哲維, dtype: int64

# %%
df.iloc[2]
# Out:
# 國文    22
# 英文    20
# 數學    46
# 理化    37
# Name: 周哲維, dtype: int64

# %%
df.loc['周哲維':'吳于庭']
# Out:
#      國文  英文  數學  理化
# 周哲維  22  20  46  37
# 張雅君  32  20  70  80
# 吳于庭  53  37  62  69

# %%
df.iloc[2:4]
# Out:
#      國文  英文  數學  理化
# 周哲維  22  20  46  37
# 張雅君  32  20  70  80

# %%
df.iloc[2, 2]
# Out:
# 46

# %%
df.iloc[2, 1:3]
# Out:
# 英文    20
# 數學    46
# Name: 周哲維, dtype: int64

# %% [markdown]
# ## 簡單的數學運算

# %%
df
# Out:
#      國文   英文  數學  理化
# 蕭念宜  92   20  65  28
# 林慧萍  97   75  32  63
# 周哲維  22   20  46  37
# 張雅君  32   20  70  80
# 吳于庭  53   37  62  69
# 關詩婷  41   31  78  81
# 黃韻宇  54   66  97  43
# 張侑花  36   68  66  84
# 李志文  49   82  86  37
# 陳如君  26  100  44  79

# %%
df.sum()
# Out:
# 國文    502
# 英文    519
# 數學    646
# 理化    601
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 蕭念宜    205
# 林慧萍    267
# 周哲維    125
# 張雅君    202
# 吳于庭    221
# 關詩婷    231
# 黃韻宇    260
# 張侑花    254
# 李志文    254
# 陳如君    249
# dtype: int64

# %%
df['總分'] = df.sum(axis=1)

# %%
df
# Out:
#      國文   英文  數學  理化   總分
# 蕭念宜  92   20  65  28  205
# 林慧萍  97   75  32  63  267
# 周哲維  22   20  46  37  125
# 張雅君  32   20  70  80  202
# 吳于庭  53   37  62  69  221
# 關詩婷  41   31  78  81  231
# 黃韻宇  54   66  97  43  260
# 張侑花  36   68  66  84  254
# 李志文  49   82  86  37  254
# 陳如君  26  100  44  79  249

# %% [markdown]
# ## 排序成績

# %%
df
# Out:
#      國文   英文  數學  理化   總分
# 蕭念宜  92   20  65  28  205
# 林慧萍  97   75  32  63  267
# 周哲維  22   20  46  37  125
# 張雅君  32   20  70  80  202
# 吳于庭  53   37  62  69  221
# 關詩婷  41   31  78  81  231
# 黃韻宇  54   66  97  43  260
# 張侑花  36   68  66  84  254
# 李志文  49   82  86  37  254
# 陳如君  26  100  44  79  249

# %%
df.sort_values('總分')
# Out:
#      國文   英文  數學  理化   總分
# 周哲維  22   20  46  37  125
# 張雅君  32   20  70  80  202
# 蕭念宜  92   20  65  28  205
# 吳于庭  53   37  62  69  221
# 關詩婷  41   31  78  81  231
# 陳如君  26  100  44  79  249
# 張侑花  36   68  66  84  254
# 李志文  49   82  86  37  254
# 黃韻宇  54   66  97  43  260
# 林慧萍  97   75  32  63  267

# %%
df.sort_values('總分',ascending=False)
# Out:
#      國文   英文  數學  理化   總分
# 林慧萍  97   75  32  63  267
# 黃韻宇  54   66  97  43  260
# 張侑花  36   68  66  84  254
# 李志文  49   82  86  37  254
# 陳如君  26  100  44  79  249
# 關詩婷  41   31  78  81  231
# 吳于庭  53   37  62  69  221
# 蕭念宜  92   20  65  28  205
# 張雅君  32   20  70  80  202
# 周哲維  22   20  46  37  125

# %% [markdown]
# ## Filtering / Boolean Indexing

# %%
df
# Out:
#      國文   英文  數學  理化   總分
# 蕭念宜  92   20  65  28  205
# 林慧萍  97   75  32  63  267
# 周哲維  22   20  46  37  125
# 張雅君  32   20  70  80  202
# 吳于庭  53   37  62  69  221
# 關詩婷  41   31  78  81  231
# 黃韻宇  54   66  97  43  260
# 張侑花  36   68  66  84  254
# 李志文  49   82  86  37  254
# 陳如君  26  100  44  79  249

# %%
df['數學']

# %%
df['數學'] < 60

# %%
df[df['數學'] < 60]
# Out:
#      國文   英文  數學  理化   總分
# 林慧萍  97   75  32  63  267
# 周哲維  22   20  46  37  125
# 陳如君  26  100  44  79  249

# %%
df[df['理化'] < 60]
# Out:
#      國文  英文  數學  理化   總分
# 蕭念宜  92  20  65  28  205
# 周哲維  22  20  46  37  125
# 黃韻宇  54  66  97  43  260
# 李志文  49  82  86  37  254

# %%
df[(df['數學'] < 60)&(df['理化'] < 60)]
# Out:
#      國文  英文  數學  理化   總分
# 周哲維  22  20  46  37  125

# %% [markdown]
# ## 讀取上市公司基本資料

# %% [markdown]
# https://mopsfin.twse.com.tw/opendata/t187ap03_L.csv

# %%
url = "https://mopsfin.twse.com.tw/opendata/t187ap03_L.csv"

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   出表日期               990 non-null    int64
#  1   公司代號               990 non-null    int64
#  2   公司名稱               990 non-null    object
#  3   公司簡稱               990 non-null    object
#  4   外國企業註冊地國           990 non-null    object
#  5   產業別                990 non-null    int64
#  6   住址                 990 non-null    object
#  7   營利事業統一編號           990 non-null    int64
#  8   董事長                990 non-null    object
#  9   總經理                987 non-null    object
#  10  發言人                990 non-null    object
#  11  發言人職稱              990 non-null    object
#  12  代理發言人              987 non-null    object
#  13  總機電話               990 non-null    object
#  14  成立日期               990 non-null    int64
#  15  上市日期               990 non-null    int64
# ...

# %%
df.head()
# Out:
#       出表日期  公司代號        公司名稱 公司簡稱 外國企業註冊地國  產業別                      住址  \
# 0  1120724  1101  臺灣水泥股份有限公司   台泥       －     1           台北市中山北路2段113號
# 1  1120724  1102  亞洲水泥股份有限公司   亞泥       －     1  台北市大安區敦化南路2段207號30、31樓
# 2  1120724  1103  嘉新水泥股份有限公司   嘉泥       －     1            台北市中山北路2段96號
# 3  1120724  1104  環球水泥股份有限公司   環泥       －     1        台北市南京東路二段125號10樓
# 4  1120724  1108  幸福水泥股份有限公司   幸福       －     1           台北市松江路237號15樓
#
#    營利事業統一編號  董事長  總經理  ...              過戶地址      簽證會計師事務所 簽證會計師1 簽證會計師2  \
# 0  11913502  張安平  程耀輝  ...    台北市重慶南路一段83號5樓  勤業眾信聯合會計師事務所    翁雅玲    黃惠敏
# 1   3244509  徐旭東  李坤炎  ...   新北市板橋區新站路16號13樓  勤業眾信聯合會計師事務所    戴信維    陳培德
# 2  11892801  張剛綸  王立心  ...  台北市敦化南路2段97號地下2樓  勤業眾信聯合會計師事務所    陳薔旬    梁盛泰
# 3   7568009  侯博義  侯智升  ...       台北市博愛路17號3樓  勤業眾信聯合會計師事務所    李季珍    楊朝欽
# 4  40601248  陳兩傳  陳兩傳  ...    台北市中正區博愛路17號3樓  勤業眾信聯合會計師事務所    陳招美    陳薔旬
#
#            英文簡稱                                             英文通訊地址  \
# ...

# %%
df['公司代號'] == 1101
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# Name: 公司代號, Length: 990, dtype: bool

# %%
df[df['公司代號'] == 1101]
# Out:
#       出表日期  公司代號        公司名稱 公司簡稱 外國企業註冊地國  產業別             住址  營利事業統一編號  董事長  \
# 0  1120724  1101  臺灣水泥股份有限公司   台泥       －     1  台北市中山北路2段113號  11913502  張安平
#
#    總經理  ...            過戶地址      簽證會計師事務所 簽證會計師1 簽證會計師2  英文簡稱  \
# 0  程耀輝  ...  台北市重慶南路一段83號5樓  勤業眾信聯合會計師事務所    翁雅玲    黃惠敏   TCC
#
#                                               英文通訊地址          傳真機號碼  \
# 0  No.113, Sec.2, Zhongshan N. Rd.,Taipei City 10...  (02)2531-6529
#
#                      電子郵件信箱                           網址  已發行普通股數或TDR原股發行股數
# 0  finance@taiwancement.com  http://www.taiwancement.com         7156181742
#
# [1 rows x 33 columns]

# %%
df[df['公司代號'] == 2330]
# Out:
#         出表日期  公司代號            公司名稱 公司簡稱 外國企業註冊地國  產業別            住址  營利事業統一編號  \
# 274  1120724  2330  台灣積體電路製造股份有限公司  台積電       －    24  新竹科學園區力行六路8號  22099131
#
#      董事長      總經理  ...            過戶地址      簽證會計師事務所 簽證會計師1 簽證會計師2  英文簡稱  \
# 274  劉德音  總裁: 魏哲家  ...  台北市重慶南路一段83號5樓  勤業眾信聯合會計師事務所    吳世宗    林尚志  TSMC
#
#                                                 英文通訊地址       傳真機號碼  \
# 274  No. 8, Li-Hsin Rd. 6, Hsinchu Science Park,Hsi...  03-5797337
#
#               電子郵件信箱                    網址  已發行普通股數或TDR原股發行股數
# 274  invest@tsmc.com  https://www.tsmc.com        25932070992
#
# [1 rows x 33 columns]

# %% [markdown]
# ## 檢視一下 gapminder 資料集
#
# https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv

# %%
url = "https://raw.githubusercontent.com/plotly/datasets/master/gapminder2007.csv"

# %%
df = pd.read_csv(url)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    142 non-null    object
#  1   pop        142 non-null    float64
#  2   continent  142 non-null    object
#  3   lifeExp    142 non-null    float64
#  4   gdpPercap  142 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 5.7+ KB

# %%
df.head()
# Out:
#        country         pop continent  lifeExp     gdpPercap
# 0  Afghanistan  31889923.0      Asia   43.828    974.580338
# 1      Albania   3600523.0    Europe   76.423   5937.029526
# 2      Algeria  33333216.0    Africa   72.301   6223.367465
# 3       Angola  12420476.0    Africa   42.731   4797.231267
# 4    Argentina  40301927.0  Americas   75.320  12779.379640

# %%
df[df['country']=='Canada']
# Out:
#    country         pop continent  lifeExp    gdpPercap
# 20  Canada  33390141.0  Americas   80.653  36319.23501

# %%
df[df['continent']=='Americas']
# Out:
#                  country          pop continent  lifeExp     gdpPercap
# 4              Argentina   40301927.0  Americas   75.320  12779.379640
# 11               Bolivia    9119152.0  Americas   65.554   3822.137084
# 14                Brazil  190010647.0  Americas   72.390   9065.800825
# 20                Canada   33390141.0  Americas   80.653  36319.235010
# 23                 Chile   16284741.0  Americas   78.553  13171.638850
# 25              Colombia   44227550.0  Americas   72.889   7006.580419
# 29            Costa Rica    4133884.0  Americas   78.782   9645.061420
# 32                  Cuba   11416987.0  Americas   78.273   8948.102923
# 36    Dominican Republic    9319622.0  Americas   72.235   6025.374752
# 37               Ecuador   13755680.0  Americas   74.994   6873.262326
# 39           El Salvador    6939688.0  Americas   71.878   5728.353514
# 50             Guatemala   12572928.0  Americas   70.259   5186.050003
# ...

# %%
df[df['continent']=='Asia']
# Out:
#                 country           pop continent  lifeExp     gdpPercap
# 0           Afghanistan  3.188992e+07      Asia   43.828    974.580338
# 7               Bahrain  7.085730e+05      Asia   75.635  29796.048340
# 8            Bangladesh  1.504483e+08      Asia   64.062   1391.253792
# 18             Cambodia  1.413186e+07      Asia   59.723   1713.778686
# 24                China  1.318683e+09      Asia   72.961   4959.114854
# 55     Hong Kong, China  6.980412e+06      Asia   82.208  39724.978670
# 58                India  1.110396e+09      Asia   64.698   2452.210407
# 59            Indonesia  2.235470e+08      Asia   70.650   3540.651564
# 60                 Iran  6.945357e+07      Asia   70.964  11605.714490
# 61                 Iraq  2.749964e+07      Asia   59.545   4471.061906
# 63               Israel  6.426679e+06      Asia   80.745  25523.277100
# 66                Japan  1.274680e+08      Asia   82.603  31656.068060
# ...

# %% [markdown]
# ### 產生練習用的資料集

# %%
from random import choice
from random import random

# %%
sizes = [(800, 600), (400, 300), (1600, 1200)]

# %%
data = []

# %%
choice(sizes)
# Out:
# (800, 600)

# %%
random?

# %%
for i in range(1000):
  size = choice(sizes)
  x = random()*size[0]
  y = random()*size[1]
  data.append((size, x, y))

# %%
data
# Out:
# [((1600, 1200), 692.5721235746737, 468.51443554611444),
#  ((800, 600), 322.3904383708227, 256.2352500528795),
#  ((400, 300), 141.14365317809708, 251.47925859754486),
#  ((400, 300), 274.60474976028115, 53.97098469375715),
#  ((800, 600), 313.0964667155546, 296.1713286859089),
#  ((400, 300), 235.9325397348964, 251.3575101666168),
#  ((400, 300), 323.45872141807513, 199.9484549276855),
#  ((800, 600), 135.1911543985312, 264.0892161731911),
#  ((1600, 1200), 899.3861427853178, 749.2189436161859),
#  ((1600, 1200), 1566.3014352221264, 872.6024499256017),
#  ((800, 600), 402.14025971768604, 27.380244017766042),
#  ((1600, 1200), 1484.6719467726762, 896.200144927451),
#  ((800, 600), 348.27102735328054, 207.6604741542296),
#  ((1600, 1200), 1384.4855834641241, 923.9515643424014),
#  ((400, 300), 247.45952648090378, 49.40876816040009),
#  ((800, 600), 503.48068553711533, 356.3846968636805),
#  ((1600, 1200), 1391.4382855902063, 575.4607352162146),
# ...

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#               0           1           2
# 0  (1600, 1200)  692.572124  468.514436
# 1    (800, 600)  322.390438  256.235250
# 2    (400, 300)  141.143653  251.479259
# 3    (400, 300)  274.604750   53.970985
# 4    (800, 600)  313.096467  296.171329

# %%
df.columns = ['size','x','y']

# %%
df.head()
# Out:
#            size           x           y
# 0  (1600, 1200)  692.572124  468.514436
# 1    (800, 600)  322.390438  256.235250
# 2    (400, 300)  141.143653  251.479259
# 3    (400, 300)  274.604750   53.970985
# 4    (800, 600)  313.096467  296.171329

# %%
df['size']==(400, 300)
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999     True
# Name: size, Length: 1000, dtype: bool

# %%
df[df['size']==(400, 300)]
# Out:
#            size           x           y
# 2    (400, 300)  141.143653  251.479259
# 3    (400, 300)  274.604750   53.970985
# 5    (400, 300)  235.932540  251.357510
# 6    (400, 300)  323.458721  199.948455
# 14   (400, 300)  247.459526   49.408768
# ..          ...         ...         ...
# 988  (400, 300)  344.572094  216.294977
# 989  (400, 300)  182.044042  262.770632
# 990  (400, 300)  320.775861  281.279034
# 995  (400, 300)  336.668421  232.695547
# 999  (400, 300)   20.570003   36.624295
#
# [326 rows x 3 columns]

# %%
import plotly.express as px

# %%
px.scatter(df[df['size']==(400, 300)], x='x', y='y')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
